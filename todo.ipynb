# %% [markdown]
# # 🚀 Data Science & AI/ML Roadmap (TODO Plan)
# ## 📌 Goal
# Data Scientist / ML Engineer
# ---
#
# # ✅ Phase 1: Python + Math Foundations
#
# ## 🐍 Python Revision
# - [ ] Revise OOP (classes, inheritance, polymorphism)
# - [ ] Practice file handling (CSV, JSON)
# - [ ] Learn exception handling
# - [ ] Practice modules & packages
#
# ## 📊 Mathematics
# - [ ] Linear Algebra (vectors, matrices)
# - [ ] Statistics (mean, median, variance, std dev)
# - [ ] Probability basics
# - [ ] Basic calculus (derivatives concept)
#
# ---
#
# # ✅ Phase 2: Data Analysis
#
# ## 📚 Libraries
# - [ ] Learn NumPy
# - [ ] Learn Pandas
# - [ ] Learn Matplotlib
# - [ ] Learn Seaborn
#
# ## 🧹 Data Preprocessing
# - [ ] Handle missing values
# - [ ] Handle outliers
# - [ ] Encode categorical data (One-hot, Label)
# - [ ] Feature scaling (StandardScaler, MinMaxScaler)
#
# ## 🔍 EDA (Exploratory Data Analysis)
# - [ ] Understand distributions
# - [ ] Correlation analysis
# - [ ] Visualization practice
#
# ---
#
# # ✅ Phase 3: Machine Learning (Core)
#
# ## 🤖 Supervised Learning
# - [ ] Linear Regression
# - [ ] Logistic Regression
# - [ ] KNN
# - [ ] Decision Tree
# - [ ] Random Forest
#
# ## 🔄 Unsupervised Learning
# - [ ] K-Means Clustering
# - [ ] Hierarchical Clustering
#
# ## ⚙️ Concepts
# - [ ] Train-Test Split
# - [ ] Cross Validation
# - [ ] Bias vs Variance
# - [ ] Overfitting / Underfitting
#
# ---
#
# # ✅ Phase 4: Model Evaluation
#
# ## 📏 Regression Metrics
# - [ ] MAE
# - [ ] MSE
# - [ ] RMSE
# - [ ] R² Score
#
# ## 📊 Classification Metrics
# - [ ] Accuracy
# - [ ] Precision
# - [ ] Recall
# - [ ] F1 Score
#
# ---
#
# # ✅ Phase 5: Advanced ML
#
# - [ ] Ridge Regression (L2)
# - [ ] Lasso Regression (L1)
# - [ ] ElasticNet
# - [ ] Feature Selection (SelectKBest, etc.)
# - [ ] Pipelines (sklearn Pipeline)
# - [ ] Hyperparameter tuning (GridSearchCV)
#
# ---
#
# # ✅ Phase 6: Projects (VERY IMPORTANT 🔥)
#
# ## 🟢 Beginner
# - [ ] House Price Prediction
# - [ ] Spam Email Classifier
#
# ## 🟡 Intermediate
# - [ ] Customer Churn Prediction
# - [ ] Loan Approval Prediction
#
# ## 🔴 Advanced
# - [ ] End-to-End ML Project (with deployment)
#
# ---
#
# # ✅ Phase 7: Deep Learning (Optional)
#
# - [ ] Neural Networks basics
# - [ ] TensorFlow / PyTorch intro
# - [ ] Build image classifier
# - [ ] Digit recognition project
#
# ---
#
# # ✅ Phase 8: Deployment
#
# - [ ] Learn Flask / FastAPI
# - [ ] Build ML API
# - [ ] Deploy on Render / Railway
# - [ ] Learn basic Docker (optional)
#
# ---
#
# # ✅ Phase 9: SQL for Data Science
#
# - [ ] Joins (INNER, LEFT, RIGHT)
# - [ ] Subqueries
# - [ ] Aggregations (GROUP BY)
# - [ ] Window functions
#
# ---
#
# # ✅ Phase 10: Career Prep
#
# - [ ] Build GitHub portfolio
# - [ ] Upload all projects
# - [ ] Create resume
# - [ ] Practice interview questions
# - [ ] Start applying for internships
#
# ---
#
# # 📅 Weekly Tracking
#
# ## Week 1-2
# - [ ] Python + Math
#
# ## Week 3-4
# - [ ] Data Analysis
#
# ## Week 5-8
# - [ ] Machine Learning
#
# ## Week 9-12
# - [ ] Advanced ML + Projects
#
# ## Week 13-16
# - [ ] Deployment + Resume
#
# ---
#
# # 🎯 Daily Routine
#
# - [ ] 2 hrs learning
# - [ ] 2 hrs coding/practice
# - [ ] 1 dataset work
# - [ ] 1 revision session
#
# ---
#
# # 🧠 Golden Rules
#
# - [ ] Practice > Watching videos
# - [ ] Projects > Theory
# - [ ] Consistency is key
# - [ ] Focus on real datasets
#
# ---
#
# # 🚀 Final Goal Checklist
#
# - [ ] 4+ ML Projects completed
# - [ ] 1 deployed project
# - [ ] Strong Python + ML basics
# - [ ] Ready for internship/job
