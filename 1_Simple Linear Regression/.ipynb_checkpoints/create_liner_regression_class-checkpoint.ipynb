# %% [markdown]
# https://chatgpt.com/share/6968a091-5524-800d-98fc-0b6a2b4c8eba

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('./placement.csv')

# %%
plt.scatter(df['cgpa'],df['package'])
plt.show()

# %%
df.head() # this is data set
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %% [markdown]
# ### create Linear Regression in Machine learning class it's self

# %%
class MeraLr:

    def __init__(self):
        self.m = None
        self.b = None

    def fit(self,X_train,y_train):
        num = 0
        den = 0

        for i in range(X_train.shape[0]):
            num += (X_train[i] - X_train.mean()) * (y_train[i] - y_train.mean())
            den +=  (X_train[i] - X_train.mean()) * (X_train[i] - X_train.mean())


        self.m = num / den
        self.b = y_train.mean() - (self.m * X_train.mean())

        print(self.m,self.b)

    def predict(self,X_test):
        return self.m * X_test + self.b

# %%
X = df.iloc[:,0].values
y = df.iloc[:,1].values

# %%
mlr = MeraLr()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=2,test_size=0.2)

# %%
mlr.fit(X_train,y_train)
# Out:
# 0.5579519734250721 -0.8961119222429152

# %%
mlr.predict(X_test)
# Out:
# array([3.89111601, 3.09324469, 2.38464568, 2.57434935, 1.6537286 ,
#        1.77647803, 2.07219258, 2.93143862, 3.76278706, 2.93701814,
#        4.09197872, 3.51170867, 2.97049525, 2.40138424, 3.18809652,
#        3.46707251, 1.94386362, 3.24389172, 2.97607477, 3.41685683,
#        2.55761079, 3.16577844, 2.85890486, 3.12114229, 3.68467378,
#        2.8700639 , 3.49497011, 3.34432308, 3.91901361, 1.96060218,
#        3.65119666, 3.2104146 , 3.74046898, 2.7863711 , 2.78079158,
#        3.27178932, 3.52844723, 2.61340599, 2.65804215, 2.71383735])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,mlr.predict(X_train),color='red')
