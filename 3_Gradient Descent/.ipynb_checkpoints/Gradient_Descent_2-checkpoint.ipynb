# %% [markdown]
# - Batch Gradient Descent
# - https://chatgpt.com/c/6975e331-2cf4-8322-81e6-878eac75c2d8

# %% [markdown]
# ![image.png](attachment:e10ea2bd-1e87-4d91-bb74-d49e555cdba3.png)

# %% [markdown]
# ![image.png](attachment:1665add2-4e86-4cb4-bd3f-5d1453b5c9e9.png)
# ![image.png](attachment:c6c50377-750f-4fa4-9cda-8d5557ad6471.png)

# %%
from sklearn.datasets import load_diabetes

import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
X,y = load_diabetes(return_X_y=True)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=2,test_size=0.2)

# %%
Lr = LinearRegression()
Lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(Lr.coef_)
print(Lr.intercept_)
# Out:
# [  -9.15865318 -205.45432163  516.69374454  340.61999905 -895.5520019
#   561.22067904  153.89310954  126.73139688  861.12700152   52.42112238]
# 151.88331005254167

# %%
r2_score(y_test,Lr.predict(X_test))
# Out:
# 0.439933866156897

# %%
Lr.predict(X_train)
# Out:
# array([ 69.58894843, 159.60631862,  42.5604978 , 187.66050206,
#         82.94854508, 138.26162086, 258.52312974, 152.88397081,
#        195.8745644 , 157.158263  , 171.29054059, 115.32126336,
#        139.25761326,  95.35823382, 172.94141449, 152.7723085 ,
#        185.10384363, 116.08156703, 143.37323396, 180.74779311,
#        146.04229986, 235.81306795, 158.26801883, 237.68286788,
#        169.36469654,  57.97186953, 108.81565739,  69.75842723,
#        154.42915667, 196.03965176,  73.61498519, 200.88252641,
#        265.38351183, 177.19447603, 201.12946216, 267.16629599,
#        195.68976964, 171.46529186,  55.55522792, 175.68148778,
#         48.34321142, 126.98160707,  92.63774709, 106.8884341 ,
#        161.77320931,  35.21712327, 109.80602681, 164.35025132,
#        145.57120278, 178.94803687, 223.43112732, 289.40573296,
#        187.86827812, 147.1548003 , 135.95638581, 118.32339114,
#        119.31550388, 108.61550956, 169.82873534,  79.68735732,
# ...

# %% [markdown]
# ![image.png](attachment:85658172-9cae-4b03-b301-819502863aa0.png)

# %%
print(y_train.shape)
print(X_train.shape)
coef = np.ones(X_train.shape[1])
np.dot(X_train,coef).shape
##  353 10
##  10  1
##  353 1
# Out:
# (353,)
# (353, 10)
# (353,)

# %%
a = np.array([[1,2,3],[4,5,6]])
b = np.ones(a.shape[1])
print(a.shape,b.shape)
# Out:
# (2, 3) (3,)

# %%
c = np.dot(a,b)
c
# Out:
# array([ 6., 15.])

# %%
X_train.T.shape,y_train.shape
# Out:
# ((10, 353), (353,))

# %%
class GDRegressor:
    def __init__(self,learning_rate=0.01,epochs=1000):
        self.coef_ = None ## x
        self.intercept_ = None ## bita
        self.lr = learning_rate
        self.epochs = epochs

    def fit(self,X_train,y_train):
        # init your coef
        self.intercept_ = 0
        self.coef_ = np.ones(X_train.shape[1])
        
        for _ in range(self.epochs):
            #update all the coef and the intercept
            # Vectorization
            y_hat = np.dot(X_train,self.coef_) + self.intercept_
            intercept_der = -2 * np.mean(y_train - y_hat)
            self.intercept_ = self.intercept_ - (self.lr * intercept_der)

            coef_der = -2 * np.dot((y_train - y_hat),X_train) / X_train.shape[0] 
            self.coef_ = self.coef_ - (self.lr * coef_der)

            # New coef_/intercept_ = Old coef_/intercept_ − (learning rate × gradient(slop))
            
        print(self.coef_,self.intercept_)
        
        

    def predict(self,X_test):
        return np.dot(X_test,self.coef_) + self.intercept_

# %%
gdr = GDRegressor(epochs=1000,learning_rate=0.5)

# %%
gdr.fit(X_train,y_train)
# Out:
# [  14.38990585 -173.7235727   491.54898524  323.91524824  -39.32648042
#  -116.01061213 -194.04077415  103.38135565  451.63448787   97.57218278] 152.01351687661833

# %%
r2_score(y_test,gdr.predict(X_test))
# Out:
# 0.4534503034722803
