# %% [markdown]
# ## ``` 👉 Type of feature selection technique's ```
# - https://www.geeksforgeeks.org/machine-learning/feature-selection-techniques-in-machine-learning/
# ---
# <b>
# 1️⃣ Filter Methods </br>
# 2️⃣ Wrapper Methods </br>
# 3️⃣ Embedded Methods </br>
# 4️⃣ Hybrid Methods (Optional)
# </b>
